# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns
import os
import pickle

# %% [markdown]
# ### NOTE -
# Run the following code only once at the starting of the project

# %%
# Importing and saving the data
def save():
    # Move to the main directory of the project
    #os.chdir("..")
    file_path = os.path.abspath(os.curdir)
    file_path_data = os.path.join(file_path, 'data/') # file path containing the dataset
    file_names = os.listdir(file_path_data) # dataset file names
    print('Reading from', file_path_data)

    # Creating the data frames of the data present
    print('Creating dataframes...')
    customer_data = pd.read_excel(os.path.join(file_patclh_data, file_names[0]))
    final_invoice = pd.read_csv(os.path.join(file_path_data, file_names[1]))
    jtd = pd.read_csv(os.path.join(file_path_data, file_names[2]))
    plant_master = pd.read_excel(os.path.join(file_path_data, file_names[4]))

    # Saving the pickle files of the dataframes for fast importing of the data
    print('Saving the pickled files...')
    customer_data.to_pickle(os.path.join(file_path , r'pickled\customer_data.pkl'))
    final_invoice.to_pickle(os.path.join(file_path , r'pickled\final_invoice.pkl'))
    jtd.to_pickle(os.path.join(file_path , r'pickled\jtd.pkl'))
    plant_master.to_pickle(os.path.join(file_path , r'pickled\plant_master.pkl'))

save()

# %%
# Loading the pickled data
customer_data = pd.read_pickle(r'pickled\customer_data.pkl')
final_invoice = pd.read_pickle(r'pickled\final_invoice.pkl')
jtd = pd.read_pickle(r'pickled\jtd.pkl')
plant_master = pd.read_pickle(r'pickled/plant_master.pkl')

# %%
top_50_model = final_invoice[['Customer No.', 'Model']]

# %%
grouped_top_50_model = top_50_model.groupby('Model').count()
grouped_top_50_model.columns = ['No. of Customers']
sorted_top_50_model = grouped_top_50_model.sort_values('No. of Customers', ascending=False)

# %%
sorted_top_50_model.reset_index(inplace=True)
temp0= sorted_top_50_model.loc[:50]

# %%
fig, ax = plt.subplots(figsize=[30, 20])
sns.barplot(x="Model", y="No. of Customers", data=temp0, ax=ax)
ax.set_title("No. of Cars per Model")
ax.set_xlabel("Models")
ax.set_ylabel("No. of cars")
plt.xticks(rotation=90)
plt.rc('xtick', labelsize=16)
plt.rc('ytick', labelsize=16)
plt.rcParams.update({'font.size': 16})
#plt.savefig(r'images/top_50_model.png')
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %%
geo_district = final_invoice[['Customer No.', 'District']]
geo_district = geo_district.groupby('District').count()
geo_district.columns = ['No. of Customers']
sorted_geo_district = geo_district.sort_values('No. of Customers', ascending=False)
sorted_geo_district.reset_index(inplace=True)
temp1 = sorted_geo_district.loc[:50]

# %%
temp1.head()
# Out:
#          District  No. of Customers
# 0     Maharashtra            128119
# 1      Tamil Nadu            116309
# 2       Karnataka             44135
# 3  Andhra Pradesh             40604
# 4   Uttar Pradesh             31534

# %%
geo_district_order = final_invoice[['Customer No.', 'Order Type', 'District']]
geo_district_order = geo_district_order.groupby(['Order Type', 'District']).count()
geo_district_order.columns = ["No. of Customers"]
#sorted_geo_district_order = geo_district_order.sort_values('Order Type', ascending=False)

# %%
geo_district_order.sort_values(['Order Type', 'No. of Customers'], ascending=[True, False], inplace=True)

# %%
final_invoice['Order Type'].unique()
# Out:
# array(['Paid Service', 'SMC Value Package', 'Running Repairs',
#        'SMC Redemption', 'Accidental', 'Repeat Order', 'Workshop Damage',
#        'Mechanical', 'WBW Order'], dtype=object)

# %%
order_type = ['Paid Service', 'SMC Value Package', 'Running Repairs',
       'SMC Redemption', 'Accidental', 'Repeat Order', 'Workshop Damage',
       'Mechanical', 'WBW Order']
for order in order_type:
    print(order)
    print(geo_district_order.loc[order], "\n")
# Out:
# Paid Service
#                       No. of Customers
# District
# Maharashtra                      43842
# Tamil Nadu                       28607
# Karnataka                        10601
# Andhra Pradesh                   10112
# Uttar Pradesh                     7723
# Gujarat                           6908
# Punjab                            5289
# Madhya Pradesh                    3964
# Haryana                           3514
# Rajasthan                         3304
# Telangana                         2215
# Kerala                            1404
# Puducherry                        1318
# Bihar                             1201
# Himachal Pradesh                   947
# Uttarakhand                        930
# Delhi                              924
# Chandigarh                         862
# Odisha                             429
# Chhattisgarh                       389
# West Bengal                        197
# Assam                               80
# Dadra and Nagar Hav.                79
# Jharkhand                           73
# Daman and Diu                       40
# Nagaland                            11
# Arunachal Pradesh                   10
# Jammu and Kashmir                    9
# Goa                                  8
# Megalaya                             4
# Lakshadweep                          2
# Manipur                              2
# Mizoram                              2
# Tripura                              2
# Andaman and Nico.In.                 1
# Sikkim                               1
#
# SMC Value Package
#                       No. of Customers
# District
# Maharashtra                       3540
# Uttar Pradesh                     1550
# Tamil Nadu                        1072
# Haryana                            850
# Andhra Pradesh                     739
# Punjab                             649
# Karnataka                          485
# Delhi                              331
# Gujarat                            237
# Chandigarh                         128
# Kerala                              91
# Telangana                           50
# Dadra and Nagar Hav.                18
# Madhya Pradesh                      11
# Odisha                               7
# Daman and Diu                        5
# Uttarakhand                          5
# Puducherry                           4
# Arunachal Pradesh                    2
# Bihar                                2
# Goa                                  2
# Himachal Pradesh                     2
# Jharkhand                            1
#
# Running Repairs
#                       No. of Customers
# District
# Tamil Nadu                       69584
# Maharashtra                      60811
# Karnataka                        26419
# Andhra Pradesh                   23302
# Uttar Pradesh                    16657
# Gujarat                          13970
# Punjab                           12264
# Haryana                           9573
# Rajasthan                         8228
# Madhya Pradesh                    7347
# Telangana                         4101
# Kerala                            3630
# Delhi                             2524
# Himachal Pradesh                  2005
# Bihar                             1773
# Odisha                            1769
# Chandigarh                        1497
# Uttarakhand                       1393
# West Bengal                       1037
# Dadra and Nagar Hav.               637
# Daman and Diu                      299
# Puducherry                         210
# Jharkhand                          163
# Chhattisgarh                       161
# Arunachal Pradesh                   41
# Assam                               12
# Nagaland                            11
# Jammu and Kashmir                   10
# Goa                                  6
# Andaman and Nico.In.                 5
# Lakshadweep                          5
# Sikkim                               4
# Megalaya                             3
# Tripura                              3
# Manipur                              1
#
# SMC Redemption
#                       No. of Customers
# District
# Maharashtra                       5812
# Uttar Pradesh                     2719
# Haryana                           1628
# Tamil Nadu                        1392
# Andhra Pradesh                    1147
# Punjab                            1016
# Delhi                              567
# Karnataka                          555
# Gujarat                            421
# Chandigarh                         220
# Kerala                             124
# Telangana                           63
# Dadra and Nagar Hav.                28
# Madhya Pradesh                      13
# Daman and Diu                        7
# Uttarakhand                          7
# Arunachal Pradesh                    5
# Odisha                               5
# Himachal Pradesh                     3
# Puducherry                           3
# Goa                                  2
# Jharkhand                            1
#
# Accidental
#                       No. of Customers
# District
# Tamil Nadu                       11530
# Maharashtra                       9874
# Andhra Pradesh                    4372
# Karnataka                         3792
# Punjab                            2693
# Uttar Pradesh                     2101
# Gujarat                           1931
# Haryana                           1598
# Madhya Pradesh                    1270
# Delhi                              934
# Rajasthan                          923
# Telangana                          900
# Kerala                             687
# Chandigarh                         463
# Himachal Pradesh                   224
# Bihar                              174
# Puducherry                         119
# Dadra and Nagar Hav.               111
# Uttarakhand                        104
# Odisha                              95
# West Bengal                         77
# Daman and Diu                       75
# Chhattisgarh                        72
# Jharkhand                           15
# Assam                                8
# Goa                                  6
# Arunachal Pradesh                    4
# Andaman and Nico.In.                 2
# Jammu and Kashmir                    2
# Nagaland                             2
# Sikkim                               1
#
# Repeat Order
#                       No. of Customers
# District
# Maharashtra                       1049
# Uttar Pradesh                      529
# Gujarat                            427
# Haryana                            248
# Karnataka                          246
# Tamil Nadu                         125
# Punjab                             119
# Andhra Pradesh                     102
# Delhi                               92
# Dadra and Nagar Hav.                34
# Rajasthan                           19
# Telangana                           17
# Chandigarh                          14
# Daman and Diu                       10
# Uttarakhand                          5
# Kerala                               3
# Madhya Pradesh                       2
# Himachal Pradesh                     1
# Puducherry                           1
#
# Workshop Damage
#              No. of Customers
# District
# Maharashtra                 8
# Gujarat                     3
# Tamil Nadu                  3
# Haryana                     1
# Kerala                      1
# Telangana                   1
#
# Mechanical
#                   No. of Customers
# District
# Tamil Nadu                    3996
# Maharashtra                   3182
# Karnataka                     2037
# Madhya Pradesh                 990
# Rajasthan                      989
# Andhra Pradesh                 830
# Punjab                         706
# Haryana                        558
# Gujarat                        506
# Telangana                      394
# Uttar Pradesh                  254
# Chandigarh                     134
# Himachal Pradesh               132
# Bihar                          108
# Uttarakhand                     95
# Kerala                          62
# Puducherry                      61
# Delhi                           42
# West Bengal                     21
# Jharkhand                        3
#
# WBW Order
#                   No. of Customers
# District
# Punjab                           5
# Rajasthan                        3
# Himachal Pradesh                 2
# Uttarakhand                      2
# Chandigarh                       1
# Haryana                          1
# Madhya Pradesh                   1
# Maharashtra                      1
# Uttar Pradesh                    1

# %%
revenue_order_district = final_invoice[['Order Type', 'District', 'Total Amt Wtd Tax.']]
revenue_order_district = revenue_order_district.groupby(['Order Type', 'District']).sum()
revenue_order_district.columns = ['Rev']
revenue_order_district.reset_index(inplace=True)
temp2 = pd.pivot_table(revenue_order_district, values='Rev', index=['District'], columns='Order Type')

# %%
fig, ax = plt.subplots(figsize=[30, 20])
sns.heatmap(temp2)
#plt.savefig(r'images/geo_order_heatmap.png')
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %%
km_order_rev_cluster = final_invoice[['Order Type', 'KMs Reading', 'Total Amt Wtd Tax.']]
cut = km_order_rev_cluster['KMs Reading']

# %%
pd.cut(cut, 5)
# Out:
# 0         (-9999.999, 1999999.8]
# 1         (-9999.999, 1999999.8]
# 2         (-9999.999, 1999999.8]
# 3         (-9999.999, 1999999.8]
# 4         (-9999.999, 1999999.8]
#                    ...
# 492309    (-9999.999, 1999999.8]
# 492310    (-9999.999, 1999999.8]
# 492311    (-9999.999, 1999999.8]
# 492312    (-9999.999, 1999999.8]
# 492313    (-9999.999, 1999999.8]
# Name: KMs Reading, Length: 492314, dtype: category
# Categories (5, interval[float64]): [(-9999.999, 1999999.8] < (1999999.8, 3999999.6] < (3999999.6, 5999999.4] < (5999999.4, 7999999.2] < (7999999.2, 9999999.0]]

# %%
km_order_rev_cluster['KMs Reading'].describe()
# Out:
# count    4.923140e+05
# mean     7.757703e+04
# std      1.168882e+05
# min      0.000000e+00
# 25%      3.409625e+04
# 50%      6.007850e+04
# 75%      9.376900e+04
# max      9.999999e+06
# Name: KMs Reading, dtype: float64

# %%
km_cluster = pd.cut(cut, bins=[0, 20000, 60000, 100000, 1000000], right=False)
km_cluster
# Out:
# 0            [20000, 60000)
# 1           [60000, 100000)
# 2            [20000, 60000)
# 3           [60000, 100000)
# 4            [20000, 60000)
#                 ...
# 492309      [60000, 100000)
# 492310           [0, 20000)
# 492311    [100000, 1000000)
# 492312       [20000, 60000)
# 492313    [100000, 1000000)
# Name: KMs Reading, Length: 492314, dtype: category
# Categories (4, interval[int64]): [[0, 20000) < [20000, 60000) < [60000, 100000) < [100000, 1000000)]

# %%
km_cluster_count = km_cluster.value_counts()
km_cluster_count
# Out:
# [20000, 60000)       187929
# [60000, 100000)      139241
# [100000, 1000000)    106410
# [0, 20000)            57707
# Name: KMs Reading, dtype: int64

# %%
km_order_rev_cluster['cluster'] = km_cluster
# Out:
# <ipython-input-20-303df00a2ce5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   km_order_rev_cluster['cluster'] = km_cluster

# %%
km_order_rev_cluster.head()
# Out:
#           Order Type  KMs Reading  Total Amt Wtd Tax.          cluster
# 0       Paid Service        49317             4051.95   [20000, 60000)
# 1  SMC Value Package        78584             1001.29  [60000, 100000)
# 2    Running Repairs        33985              233.14   [20000, 60000)
# 3     SMC Redemption        78584                0.00  [60000, 100000)
# 4       Paid Service        50057             2747.12   [20000, 60000)

# %%
km_order_rev_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492314 entries, 0 to 492313
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order Type          492314 non-null  object
#  1   KMs Reading         492314 non-null  int64
#  2   Total Amt Wtd Tax.  492314 non-null  float64
#  3   cluster             491287 non-null  category
# dtypes: category(1), float64(1), int64(1), object(1)
# memory usage: 11.7+ MB

# %%
km_order_rev_cluster.drop('KMs Reading', axis='columns', inplace=True)
km_order_rev_cluster = km_order_rev_cluster.groupby(['Order Type', 'cluster']).mean()
km_order_rev_cluster.reset_index(inplace=True)
temp3 = pd.pivot_table(km_order_rev_cluster, values='Total Amt Wtd Tax.', index=['Order Type'], columns='cluster')
# Out:
# C:\Users\Baby\Anaconda3\envs\py38-basic-ml\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fig, ax = plt.subplots(figsize=[30, 20])
sns.heatmap(temp3)
#plt.savefig(r'images/km_order_heatmap.png')
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %%
km_order_rev_cluster.drop('KMs Reading', axis='columns', inplace=True)
km_order_rev_cluster = km_order_rev_cluster.groupby(['Order Type', 'cluster']).mean()
km_order_rev_cluster.reset_index(inplace=True)
# Out:
# C:\Users\Baby\Anaconda3\envs\py38-basic-ml\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fig, axes = plt.subplots(1,6, figsize=[30,10], sharey='row')
sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'Running Repairs'], ax=axes[0])
sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'Paid Service'], ax=axes[1])
sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'Accidental'], ax=axes[2])
sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'SMC Value Package'], ax=axes[3])
sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'Mechanical'], ax=axes[4])
sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'WBW Order'], ax=axes[5])
#sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'SMC Redemption'], ax=axes[6])
#sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'Repeat Order'], ax=axes[6])
#sns.barplot(x='cluster', y='Total Amt Wtd Tax.', data=km_order_rev_cluster[km_order_rev_cluster['Order Type'] == 'Workshop Damage'], ax=axes[6])

for i in range(6):
    axes[i].set_xticklabels(['1', '2', '3', '4'])
    axes[i].set_xlabel("KMs Class", fontsize=12, fontweight='semibold')
    axes[i].set_ylabel("")
axes[0].set_ylabel('Avg. of Total Amt Wtd Tax.', fontsize=12, fontweight='semibold')
fig.suptitle('Distribution of Avg. Revenue based on KMS Class and Order Type', fontsize=14, fontweight='semibold')
sns.despine()
plt.savefig(r'images/km_order_rev_bar.png')
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %%
custtype_rev = final_invoice[['Cust Type', 'Total Amt Wtd Tax.', 'Order Type']]
custtype_rev_avg = custtype_rev.groupby(['Cust Type', 'Order Type']).mean()
custtype_rev_avg.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(2,1, figsize=[12,10])
sns.barplot(x='Cust Type', y='Total Amt Wtd Tax.', data=custtype_rev_avg, ax=ax[0])
sns.barplot(x='Total Amt Wtd Tax.', y='Order Type', data=custtype_rev_avg, ax=ax[1])
ax[0].set_xlabel("Customer Types", fontsize=12, fontweight='semibold')
ax[0].set_ylabel("Average Revenue", fontsize=12, fontweight='semibold')
ax[1].set_xlabel("Average Revenue", fontsize=12, fontweight='semibold')
ax[1].set_ylabel("Order Type", fontsize=12, fontweight='semibold')
sns.despine()
#plt.savefig(r'images/order_cust_rev.png')
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
fig, ax = plt.subplots(1,1, figsize=[15,12])
sns.barplot(x='Cust Type', y='Total Amt Wtd Tax.', hue='Order Type', data=custtype_rev_avg, order=['Retail', 'Corporate others', 'Corporate- M&M', 'Fleets', 'MFCWL',
       'Insurance', 'Franchise'])
ax.legend(loc=1)
ax.set_xlabel("Customer Types", fontsize=12, fontweight='semibold')
ax.set_ylabel("Average Revenue", fontsize=12, fontweight='semibold')
ax.set_title("Average Revenue Based on Customer Type", fontweight='semibold', fontsize=14)
sns.despine()
#plt.savefig(r'images/rev_cust_bar.png')
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
final_invoice['Cust Type'].unique()
# Out:
# array(['Retail', 'Corporate others', 'Corporate- M&M', 'Fleets', 'MFCWL',
#        'Insurance', 'Franchise'], dtype=object)
